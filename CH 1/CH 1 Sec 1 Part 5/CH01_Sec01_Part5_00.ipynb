# %% [markdown]
# # Chapter 1 Section 1 Part 5
#
# Tujuan dari pembelajaran pada bagian ini adalah untuk menyelesaikan pengaplikasian persamaan sistem linear
#
# #### Contoh 1 :
# diberikan persamaan sistem linear :
#
#     x + 2z      = a
#     x + y + 3z  = b
#     y + z       = c
#
# Carilah nilai a, b, dan c, agar sistem ini dapat dikatakan konsisten

# %%
from sympy import symbols, Matrix
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams['figure.figsize'] = [15,10]
plt.rcParams.update({'font.size':10})

a = symbols('a')
b = symbols('b')
c = symbols('c')

A = np.array([[1,0,2,a],
              [1,1,3,b],
              [0,1,1,c]])
r1 = A[0,:]
r2 = A[1,:]
r3 = A[2,:]
A = np.array([r1,
              r2-r1,
              r3])
r1 = A[0,:]
r2 = A[1,:]
r3 = A[2,:]
A = np.array([r1,
              r2,
              r3-r2])
print(A)
# Out:
# [[1 0 2 a]
#  [0 1 1 -a + b]
#  [0 0 0 a - b + c]]

# %%
r1 = A[0,:]
r2 = A[1,:]
r3 = A[2,:]

a = 2
b = 1
c = -1
result = np.array([a-b+c])
print('result if we let \n a = 2, b = 1, c = -1 maka hasilnya adalah =  ' + str(result))
# Out:
# result if we let
#  a = 2, b = 1, c = -1 maka hasilnya adalah =  [0]

# %%
# cara Cepat untuk mencari bentuk eselon

A = Matrix([[1,0,2,2],
              [1,1,3,1],
              [0,1,1,-1]])
System, piv = A.rref()
print(System)
# Out:
# Matrix([[1, 0, 2, 2], [0, 1, 1, -1], [0, 0, 0, 0]])

# %% [markdown]
# ## Visualisasi hasil yang kita dapatkan

# %%
# Visualize Our Answer
A = np.array([[1,0,2],
              [1,1,3],
              [0,1,1]])
pts = 1 - 2*np.random.rand(3,100)
s = np.linspace(-5,5,20)
t = np.linspace(-3,3,20)
fig = plt.figure()
S,T = np.meshgrid(s,t)
X = S-T
Y = S
Z = T
ax = fig.gca(projection='3d')
ax.plot_surface(X,Y,Z,color='b', alpha=0.5)
Tpts = np.dot(A,pts)
ax.scatter(Tpts[0,:],Tpts[1,:],Tpts[2,:], color='r')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')

plt.show()
